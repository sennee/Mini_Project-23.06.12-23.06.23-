# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # df_train_v3_mean_m1
# - v2로 모델 돌리면 너무 데이터의 범위가 촘촘해서 과적합 되는 것 같아, 훈련 데이터의 데이터의 범위를 러프하게 하고자 1분 단위 변환

# %%
### df_train_v3_mean 
df_train = pd.read_csv("./통합데이터/df_train_v2_mean.csv")

## df_anch_train (answer = 0)
df_anch_train = df_train[(df_train['answer']==0)] # 정박 

# df_lat
df_lat = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lat'].to_frame()
df_lat = df_lat.T.unstack().reset_index()
df_lat.drop(columns = ['level_5'], inplace = True)
df_lat = df_lat.rename(columns = {0:'lat'})

# df_lon
df_lon = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lon'].to_frame()
df_lon = df_lon.T.unstack().reset_index()
df_lon.drop(columns = ['level_5'], inplace = True)
df_lon = df_lon.rename(columns = {0:'lon'})

# df_sog
df_sog	= round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['sog'].to_frame()
df_sog = df_sog.T.unstack().reset_index()
df_sog.drop(columns = ['level_5'], inplace = True)
df_sog = df_sog.rename(columns = {0:'sog'})

# df_cog
df_cog= round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['cog'].to_frame()
df_cog = df_cog.T.unstack().reset_index()
df_cog.drop(columns = ['level_5'], inplace = True)
df_cog = df_cog.rename(columns = {0:'cog'})

# df_hdg
df_hdg = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['hdg'].to_frame()
df_hdg = df_hdg.T.unstack().reset_index()
df_hdg.drop(columns = ['level_5'], inplace = True)
df_hdg = df_hdg.rename(columns = {0:'hdg'})

# df_khnp_buoy_train_ws
df_khnp_buoy_train_ws = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['khnp_buoy_train.ws'].to_frame()
df_khnp_buoy_train_ws = df_khnp_buoy_train_ws.T.unstack().reset_index()
df_khnp_buoy_train_ws.drop(columns = ['level_5'], inplace = True)
df_khnp_buoy_train_ws = df_khnp_buoy_train_ws.rename(columns = {0:'khnp_buoy.ws'})

# df_khnp_buoy_train_wd
df_khnp_buoy_train_wd = df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min'])['khnp_buoy_train.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
df_khnp_buoy_train_wd = df_khnp_buoy_train_wd.T.unstack().reset_index()
df_khnp_buoy_train_wd.drop(columns = ['level_5'], inplace = True)
df_khnp_buoy_train_wd = df_khnp_buoy_train_wd.rename(columns = {0:'khnp_buoy.wd'})

# df_kma_lightbecon_train_wd
df_kma_lightbecon_train_wd = df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min'])['kma_lightbecon_train.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
df_kma_lightbecon_train_wd = df_kma_lightbecon_train_wd.T.unstack().reset_index()
df_kma_lightbecon_train_wd.drop(columns = ['level_5'], inplace = True)
df_kma_lightbecon_train_wd = df_kma_lightbecon_train_wd.rename(columns = {0:'kma_lightbecon.wd'})

# df_kma_lightbecon_train_ws
df_kma_lightbecon_train_ws = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_lightbecon_train.ws'].to_frame()
df_kma_lightbecon_train_ws = df_kma_lightbecon_train_ws.T.unstack().reset_index()
df_kma_lightbecon_train_ws.drop(columns = ['level_5'], inplace = True)
df_kma_lightbecon_train_ws = df_kma_lightbecon_train_ws.rename(columns = {0:'kma_lightbecon.ws'})

# df_kma_pagobuoy_train_max_wh
df_kma_pagobuoy_train_max_wh = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.max_wh'].to_frame()
df_kma_pagobuoy_train_max_wh = df_kma_pagobuoy_train_max_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_max_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_max_wh = df_kma_pagobuoy_train_max_wh.rename(columns = {0:'kma_pagobuoy.max_wh'})

# df_kma_pagobuoy_train_sig_wh
df_kma_pagobuoy_train_sig_wh = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.sig_wh'].to_frame()
df_kma_pagobuoy_train_sig_wh = df_kma_pagobuoy_train_sig_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_sig_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_sig_wh = df_kma_pagobuoy_train_sig_wh.rename(columns = {0:'kma_pagobuoy.sig_wh'})

# df_kma_pagobuoy_train_mean_wh
df_kma_pagobuoy_train_mean_wh = round(df_anch_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.mean_wh'].to_frame()
df_kma_pagobuoy_train_mean_wh = df_kma_pagobuoy_train_mean_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_mean_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_mean_wh = df_kma_pagobuoy_train_mean_wh.rename(columns = {0:'kma_pagobuoy.mean_wh'})

## Merge
'''
df_lat
df_lon
df_sog
df_cog
df_hdg
df_khnp_buoy_train_ws
df_khnp_buoy_train_wd
df_kma_lightbecon_train_ws
df_kma_lightbecon_train_wd
df_kma_pagobuoy_train_max_wh
df_kma_pagobuoy_train_sig_wh
df_kma_pagobuoy_train_mean_wh
'''
df_0 = pd.merge(df_lat, df_lon, how='inner')
df_0 = pd.merge(df_0, df_sog, how='inner')
df_0 = pd.merge(df_0, df_sog, how='inner')
df_0 = pd.merge(df_0, df_cog, how='inner')
df_0 = pd.merge(df_0, df_hdg, how='inner')
df_0 = pd.merge(df_0, df_khnp_buoy_train_ws, how='inner')
df_0 = pd.merge(df_0, df_khnp_buoy_train_wd, how='inner')
df_0 = pd.merge(df_0, df_kma_lightbecon_train_ws, how='inner')
df_0 = pd.merge(df_0, df_kma_lightbecon_train_wd, how='inner')
df_0 = pd.merge(df_0, df_kma_pagobuoy_train_max_wh, how='inner')
df_0 = pd.merge(df_0, df_kma_pagobuoy_train_sig_wh, how='inner')
df_0 = pd.merge(df_0, df_kma_pagobuoy_train_mean_wh, how='inner')

# merge 완료한 테이블에 answer 컬럼 추가
df_0['answer'] = 0

## df_drag_train (answer = 1)
df_drag_train = df_train[(df_train['answer']==1)] # 닻끌림

# df_lat
df_lat = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lat'].to_frame()
df_lat = df_lat.T.unstack().reset_index()
df_lat.drop(columns = ['level_5'], inplace = True)
df_lat = df_lat.rename(columns = {0:'lat'})

# df_lon
df_lon = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lon'].to_frame()
df_lon = df_lon.T.unstack().reset_index()
df_lon.drop(columns = ['level_5'], inplace = True)
df_lon = df_lon.rename(columns = {0:'lon'})

### df_sog
df_sog	= round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['sog'].to_frame()
df_sog = df_sog.T.unstack().reset_index()
df_sog.drop(columns = ['level_5'], inplace = True)
df_sog = df_sog.rename(columns = {0:'sog'})

### df_cog
df_cog= round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['cog'].to_frame()
df_cog = df_cog.T.unstack().reset_index()
df_cog.drop(columns = ['level_5'], inplace = True)
df_cog = df_cog.rename(columns = {0:'cog'})

### df_hdg
df_hdg = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['hdg'].to_frame()
df_hdg = df_hdg.T.unstack().reset_index()
df_hdg.drop(columns = ['level_5'], inplace = True)
df_hdg = df_hdg.rename(columns = {0:'hdg'})

### df_khnp_buoy_train_ws
df_khnp_buoy_train_ws = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['khnp_buoy_train.ws'].to_frame()
df_khnp_buoy_train_ws = df_khnp_buoy_train_ws.T.unstack().reset_index()
df_khnp_buoy_train_ws.drop(columns = ['level_5'], inplace = True)
df_khnp_buoy_train_ws = df_khnp_buoy_train_ws.rename(columns = {0:'khnp_buoy.ws'})

### df_khnp_buoy_train_wd
df_khnp_buoy_train_wd = df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min'])['khnp_buoy_train.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
df_khnp_buoy_train_wd = df_khnp_buoy_train_wd.T.unstack().reset_index()
df_khnp_buoy_train_wd.drop(columns = ['level_5'], inplace = True)
df_khnp_buoy_train_wd = df_khnp_buoy_train_wd.rename(columns = {0:'khnp_buoy.wd'})

### df_kma_lightbecon_train_wd
df_kma_lightbecon_train_wd = df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min'])['kma_lightbecon_train.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
df_kma_lightbecon_train_wd = df_kma_lightbecon_train_wd.T.unstack().reset_index()
df_kma_lightbecon_train_wd.drop(columns = ['level_5'], inplace = True)
df_kma_lightbecon_train_wd = df_kma_lightbecon_train_wd.rename(columns = {0:'kma_lightbecon.wd'})

### df_kma_lightbecon_train_ws
df_kma_lightbecon_train_ws = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_lightbecon_train.ws'].to_frame()
df_kma_lightbecon_train_ws = df_kma_lightbecon_train_ws.T.unstack().reset_index()
df_kma_lightbecon_train_ws.drop(columns = ['level_5'], inplace = True)
df_kma_lightbecon_train_ws = df_kma_lightbecon_train_ws.rename(columns = {0:'kma_lightbecon.ws'})

### df_kma_pagobuoy_train_max_wh
df_kma_pagobuoy_train_max_wh = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.max_wh'].to_frame()
df_kma_pagobuoy_train_max_wh = df_kma_pagobuoy_train_max_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_max_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_max_wh = df_kma_pagobuoy_train_max_wh.rename(columns = {0:'kma_pagobuoy.max_wh'})

### df_kma_pagobuoy_train_sig_wh
df_kma_pagobuoy_train_sig_wh = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.sig_wh'].to_frame()
df_kma_pagobuoy_train_sig_wh = df_kma_pagobuoy_train_sig_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_sig_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_sig_wh = df_kma_pagobuoy_train_sig_wh.rename(columns = {0:'kma_pagobuoy.sig_wh'})

### df_kma_pagobuoy_train_mean_wh
df_kma_pagobuoy_train_mean_wh = round(df_drag_train.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_train.mean_wh'].to_frame()
df_kma_pagobuoy_train_mean_wh = df_kma_pagobuoy_train_mean_wh.T.unstack().reset_index()
df_kma_pagobuoy_train_mean_wh.drop(columns = ['level_5'], inplace = True)
df_kma_pagobuoy_train_mean_wh = df_kma_pagobuoy_train_mean_wh.rename(columns = {0:'kma_pagobuoy.mean_wh'})

## Merge
'''
df_lat
df_lon
df_sog
df_cog
df_hdg
df_khnp_buoy_train_ws
df_khnp_buoy_train_wd
df_kma_lightbecon_train_ws
df_kma_lightbecon_train_wd
df_kma_pagobuoy_train_max_wh
df_kma_pagobuoy_train_sig_wh
df_kma_pagobuoy_train_mean_wh
'''
df_1 = pd.merge(df_lat, df_lon, how='inner')
df_1 = pd.merge(df_1, df_sog, how='inner')
df_1 = pd.merge(df_1, df_sog, how='inner')
df_1 = pd.merge(df_1, df_cog, how='inner')
df_1 = pd.merge(df_1, df_hdg, how='inner')
df_1 = pd.merge(df_1, df_khnp_buoy_train_ws, how='inner')
df_1 = pd.merge(df_1, df_khnp_buoy_train_wd, how='inner')
df_1 = pd.merge(df_1, df_kma_lightbecon_train_ws, how='inner')
df_1 = pd.merge(df_1, df_kma_lightbecon_train_wd, how='inner')
df_1 = pd.merge(df_1, df_kma_pagobuoy_train_max_wh, how='inner')
df_1 = pd.merge(df_1, df_kma_pagobuoy_train_sig_wh, how='inner')
df_1 = pd.merge(df_1, df_kma_pagobuoy_train_mean_wh, how='inner')

# merge 완료한 테이블에 answer 컬럼 추가
df_1['answer'] = 1

# Concat
df = pd.concat([df_0,df_1], join='inner')

# csv 저장
df.to_csv("./통합데이터/df_train_v3_mean_1m.csv", index=False)

# df

# %% [markdown]
# # df_test_v3_mean
# - 1분 단위로 merge

# %%
# ### df_test_v3_mean 
# df_test = pd.read_csv("./통합데이터/df_test_v2_mean.csv")

# ## df_anch_test
# df_anch_drag_test = df_test # 정박

# ### df_lat
# df_lat = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lat'].to_frame()
# df_lat = df_lat.T.unstack().reset_index()
# df_lat.drop(columns = ['level_5'], inplace = True)
# df_lat = df_lat.rename(columns = {0:'lat'})

# ### df_lon
# df_lon = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),6)['lon'].to_frame()
# df_lon = df_lon.T.unstack().reset_index()
# df_lon.drop(columns = ['level_5'], inplace = True)
# df_lon = df_lon.rename(columns = {0:'lon'})

# ### df_sog
# df_sog = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['sog'].to_frame()
# df_sog = df_sog.T.unstack().reset_index()
# df_sog.drop(columns = ['level_5'], inplace = True)
# df_sog = df_sog.rename(columns = {0:'sog'})

# ### df_cog
# df_cog= round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['cog'].to_frame()
# df_cog = df_cog.T.unstack().reset_index()
# df_cog.drop(columns = ['level_5'], inplace = True)
# df_cog = df_cog.rename(columns = {0:'cog'})

# ### df_hdg
# df_hdg = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),1)['hdg'].to_frame()
# df_hdg = df_hdg.T.unstack().reset_index()
# df_hdg.drop(columns = ['level_5'], inplace = True)
# df_hdg = df_hdg.rename(columns = {0:'hdg'})

# ### df_khnp_buoy_test_ws
# df_khnp_buoy_test_ws = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['khnp_buoy_test.ws'].to_frame()
# df_khnp_buoy_test_ws = df_khnp_buoy_test_ws.T.unstack().reset_index()
# df_khnp_buoy_test_ws.drop(columns = ['level_5'], inplace = True)
# df_khnp_buoy_test_ws = df_khnp_buoy_test_ws.rename(columns = {0:'khnp_buoy.ws'})

# ### df_khnp_buoy_test_wd
# df_khnp_buoy_test_wd = df_anch_drag_test.groupby(['year', 'month', 'day', 'hour','min'])['khnp_buoy_test.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
# df_khnp_buoy_test_wd = df_khnp_buoy_test_wd.T.unstack().reset_index()
# df_khnp_buoy_test_wd.drop(columns = ['level_5'], inplace = True)
# df_khnp_buoy_test_wd = df_khnp_buoy_test_wd.rename(columns = {0:'khnp_buoy.wd'})

# ### df_kma_lightbecon_test_wd
# df_kma_lightbecon_test_wd = df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min'])['kma_lightbecon_test.wd'].agg(lambda x: pd.Series.mode(x)[0]).to_frame()
# df_kma_lightbecon_test_wd = df_kma_lightbecon_test_wd.T.unstack().reset_index()
# df_kma_lightbecon_test_wd.drop(columns = ['level_5'], inplace = True)
# df_kma_lightbecon_test_wd = df_kma_lightbecon_test_wd.rename(columns = {0:'kma_lightbecon.wd'})

# ### df_kma_lightbecon_test_ws
# df_kma_lightbecon_test_ws = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour','min']).mean(),2)['kma_lightbecon_test.ws'].to_frame()
# df_kma_lightbecon_test_ws = df_kma_lightbecon_test_ws.T.unstack().reset_index()
# df_kma_lightbecon_test_ws.drop(columns = ['level_5'], inplace = True)
# df_kma_lightbecon_test_ws = df_kma_lightbecon_test_ws.rename(columns = {0:'kma_lightbecon.ws'})

# ### df_kma_pagobuoy_test_max_wh
# df_kma_pagobuoy_test_max_wh = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_test.max_wh'].to_frame()
# df_kma_pagobuoy_test_max_wh = df_kma_pagobuoy_test_max_wh.T.unstack().reset_index()
# df_kma_pagobuoy_test_max_wh.drop(columns = ['level_5'], inplace = True)
# df_kma_pagobuoy_test_max_wh = df_kma_pagobuoy_test_max_wh.rename(columns = {0:'kma_pagobuoy.max_wh'})

# ### df_kma_pagobuoy_test_sig_wh
# df_kma_pagobuoy_test_sig_wh = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_test.sig_wh'].to_frame()
# df_kma_pagobuoy_test_sig_wh = df_kma_pagobuoy_test_sig_wh.T.unstack().reset_index()
# df_kma_pagobuoy_test_sig_wh.drop(columns = ['level_5'], inplace = True)
# df_kma_pagobuoy_test_sig_wh = df_kma_pagobuoy_test_sig_wh.rename(columns = {0:'kma_pagobuoy.sig_wh'})

# ### df_kma_pagobuoy_test_mean_wh
# df_kma_pagobuoy_test_mean_wh = round(df_anch_drag_test.groupby(['year', 'month', 'day', 'hour', 'min']).mean(),2)['kma_pagobuoy_test.mean_wh'].to_frame()
# df_kma_pagobuoy_test_mean_wh = df_kma_pagobuoy_test_mean_wh.T.unstack().reset_index()
# df_kma_pagobuoy_test_mean_wh.drop(columns = ['level_5'], inplace = True)
# df_kma_pagobuoy_test_mean_wh = df_kma_pagobuoy_test_mean_wh.rename(columns = {0:'kma_pagobuoy.mean_wh'})

# ## Merge
# '''
# df_lat
# df_lon
# df_sog
# df_cog
# df_hdg
# df_khnp_buoy_test_ws
# df_khnp_buoy_test_wd
# df_kma_lightbecon_test_ws
# df_kma_lightbecon_test_wd
# df_kma_pagobuoy_test_max_wh
# df_kma_pagobuoy_test_sig_wh
# df_kma_pagobuoy_test_mean_wh
# '''
# df = pd.merge(df_lat, df_lon, how='inner')
# df = pd.merge(df, df_sog, how='inner')
# df = pd.merge(df, df_sog, how='inner')
# df = pd.merge(df, df_cog, how='inner')
# df = pd.merge(df, df_hdg, how='inner')
# df = pd.merge(df, df_khnp_buoy_test_ws, how='inner')
# df = pd.merge(df, df_khnp_buoy_test_wd, how='inner')
# df = pd.merge(df, df_kma_lightbecon_test_ws, how='inner')
# df = pd.merge(df, df_kma_lightbecon_test_wd, how='inner')
# df = pd.merge(df, df_kma_pagobuoy_test_max_wh, how='inner')
# df = pd.merge(df, df_kma_pagobuoy_test_sig_wh, how='inner')
# df = pd.merge(df, df_kma_pagobuoy_test_mean_wh, how='inner')

# # csv 저장
# df.to_csv("./통합데이터/df_test_v3_mean.csv", index=False)

# # df
# Out:
#        year  month  day  hour  min        lat         lon  sog    cog    hdg  \
# 0      2022      7    1     6   59  35.487834  129.397854  0.8  327.8  151.0
# 1      2022      7    1     7    0  35.487939  129.397885  0.8  154.8  170.7
# 2      2022      7    1     7    1  35.487824  129.398020  0.8  145.6  180.1
# 3      2022      7    1     7    2  35.487625  129.398110  0.6  170.0  174.5
# 4      2022      7    1     7    3  35.487519  129.398133  0.3  181.0  166.5
# ...     ...    ...  ...   ...  ...        ...         ...  ...    ...    ...
# 37963  2023      3   23    13   39  35.445060  129.447746  2.3   74.6  114.0
# 37964  2023      3   23    13   40  35.445209  129.448589  2.6   79.4  113.3
# 37965  2023      3   23    13   41  35.445337  129.449513  2.8   81.9  111.5
# 37966  2023      3   23    13   42  35.445378  129.450498  2.9   87.6  103.0
# 37967  2023      3   23    13   43  35.445448  129.451579  3.4   80.6   91.5
#
# ...
